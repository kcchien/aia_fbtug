# %%
# !pwd
# Out:
# /home/jovyan/YOLO/keras-yolo3

# %%
# !python train.py -c config.json
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# if
# if
# Seen labels: 	{'2_pepper_matured': 117, '3_pepper_covered': 312, '1_pepper_young': 1078, '0_pepper_flower': 142}
#
# Given labels: 	['0_pepper_flower', '1_pepper_young', '2_pepper_matured', '3_pepper_covered']
#
# Training on: 	['0_pepper_flower', '1_pepper_young', '2_pepper_matured', '3_pepper_covered']
#
# 2018-11-30 16:08:55.844500: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-11-30 16:08:56.405394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1405] Found device 0 with properties:
# ...
